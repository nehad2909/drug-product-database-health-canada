# %%
import pandas as pd
import os
import shutil
import wget
import requests

# %%
# geting current directory
cwd = os.getcwd()
print(cwd)

# creating temp directory to unzip files
dir = os.path.join(cwd, "Shortage")
if not os.path.exists(dir):
    os.mkdir(dir)
# Out:
# c:\Users\lucho\OneDrive - St. Clair College\402 Capstone Project\GitHub\drug-product-database-health-canada\drug-product-database-health-canada\Scripts

# %%
# print(dir)

# %%
# Loading first ziped file 2017-2019 shortage historical
shutil.unpack_archive('Shortage/1.zip', 'Shortage')

# old_name = r"c:\Users\lucho\OneDrive - St. Clair College\402 Capstone Project\Final project\Shortage data\Zip_Files\Shortage\shortage_report_export.csv"
old_name = cwd+r"\Shortage\shortage_report_export.csv"
# new_name = r"c:\Users\lucho\OneDrive - St. Clair College\402 Capstone Project\Final project\Shortage data\Zip_Files\Shortage\shortage_report_export_1.csv"
new_name = cwd+r"\Shortage\shortage_report_export_1.csv"
os.rename(old_name, new_name)

# %%
# Loading 2nd  ziped file 2020-Present shortage historical
shutil.unpack_archive('Shortage/2.zip', 'Shortage')

# old_name = r"c:\Users\lucho\OneDrive - St. Clair College\402 Capstone Project\Final project\Shortage data\Zip_Files\Shortage\shortage_report_export.csv"
old_name = cwd+r"\Shortage\shortage_report_export.csv"

#new_name = r"c:\Users\lucho\OneDrive - St. Clair College\402 Capstone Project\Final project\Shortage data\Zip_Files\Shortage\shortage_report_export_2.csv"
new_name = cwd+r"\Shortage\shortage_report_export_2.csv"

os.rename(old_name, new_name)

# %%
shortage1 = pd.read_csv('Shortage\shortage_report_export_1.csv', header=1)

# %%
shortage1.head()
# Out:
#    Report ID  Drug Identification Number Report Type  \
# 0      75200                    437999.0    Shortage
# 1      34506                   1924303.0    Shortage
# 2      91156                     60208.0    Shortage
# 3      99361                     60208.0    Shortage
# 4      91720                     60208.0    Shortage
#
#                                           Brand name          Company Name  \
# 0  (20MMOL/L) POTASSIUM CHLORIDE IN 5% DEXTROSE A...    BAXTER CORPORATION
# 1                 0.9% SODIUM CHLORIDE INJECTION USP  B. BRAUN MEDICAL INC
# 2                0.9% SODIUM CHLORIDE INJECTION, USP    BAXTER CORPORATION
# 3                0.9% SODIUM CHLORIDE INJECTION, USP    BAXTER CORPORATION
# 4                0.9% SODIUM CHLORIDE INJECTION, USP    BAXTER CORPORATION
#
#                          Common or Proper name  \
# 0  Potassium Chloride in 5% Dextrose Injection
# 1                              Sodium Chloride
# 2          0.9% Sodium Chloride Injection, USP
# 3          0.9% SODIUM CHLORIDE INJECTION, USP
# 4          0.9% SODIUM CHLORIDE INJECTION, USP
#
#                                        Ingredients         Strength(s)  \
# 0  DEXTROSE\r POTASSIUM CHLORIDE\r SODIUM CHLORIDE  5G\r 150MG\r 450MG
# 1                                  SODIUM CHLORIDE                0.9%
# 2                                  SODIUM CHLORIDE               900MG
# 3                                  SODIUM CHLORIDE               900MG
# 4                                  SODIUM CHLORIDE               900MG
#
#                Packaging size Route of administration  ... ATC Code  \
# 0                     1000 mL             INTRAVENOUS  ...    B05BB
# 1  100mL, 150mL, 250mL, 500mL             INTRAVENOUS  ...    B05XA
# 2              50 mL (JB1301)             INTRAVENOUS  ...    B05XA
# 3              25 mL (JB1300)             INTRAVENOUS  ...    B05XA
# 4             100 mL (JB0043)             INTRAVENOUS  ...    B05XA
#
#            ATC description Anticipated start date Actual start date  \
# 0           I.V. SOLUTIONS             2019-02-08        2019-02-08
# 1  I.V. SOLUTION ADDITIVES             2017-12-22        2017-12-22
# 2  I.V. SOLUTION ADDITIVES             2019-08-08        2019-08-08
# 3  I.V. SOLUTION ADDITIVES             2019-11-20        2019-11-20
# 4  I.V. SOLUTION ADDITIVES             2019-08-16        2019-08-16
#
#   Estimated end date Actual end date  \
# 0         2019-02-12      2019-02-12
# 1                NaN      2019-01-01
# 2         2019-08-29      2019-08-29
# 3         2019-11-29      2019-11-29
# 4         2019-11-08      2019-11-08
#
#                                        Reason Date Created Date Updated Tier 3
# 0               Demand increase for the drug.   2019-02-08   2019-02-13     No
# 1  Disruption of the manufacture of the drug.   2018-01-02   2019-11-06     No
# 2           Shortage of an active ingredient.   2019-08-08   2019-08-30     No
# 3               Demand increase for the drug.   2019-11-20   2019-11-30     No
# 4           Shortage of an active ingredient.   2019-08-16   2019-11-09     No
#
# [5 rows x 22 columns]

# %%
shortage2 = pd.read_csv('Shortage\shortage_report_export_2.csv', header=1)

# %%
shortage2.head()
# Out:
#    Report ID  Drug Identification Number Report Type  \
# 0     179915                      828602    Shortage
# 1     162651                     2395150    Shortage
# 2     170890                     2395150    Shortage
# 3     160191                     2395150    Shortage
# 4     145824                     2150204    Shortage
#
#                                           Brand name  \
# 0  0.4% LIDOCAINE HYDROCHLORIDE AND 5% DEXTROSE I...
# 1                     0.9% SODIUM CHLORIDE INJECTION
# 2                     0.9% SODIUM CHLORIDE INJECTION
# 3                     0.9% SODIUM CHLORIDE INJECTION
# 4                 0.9% SODIUM CHLORIDE INJECTION USP
#
#                  Company Name  \
# 0          BAXTER CORPORATION
# 1   FRESENIUS KABI CANADA LTD
# 2   FRESENIUS KABI CANADA LTD
# 3   FRESENIUS KABI CANADA LTD
# 4  OMEGA LABORATORIES LIMITED
#
#                                Common or Proper name  \
# 0  0.4% LIDOCAINE HYDROCHLORIDE AND 5% DEXTROSE I...
# 1            Sodium Chloride 0.9% freeflex® Bag 50mL
# 2                     0.9% SODIUM CHLORIDE INJECTION
# 3                     Sodium Chloride 0.9% Injection
# 4                  Sodium Chloride for Injection USP
#
#                           Ingredients Strength(s)          Packaging size  \
# 0  DEXTROSE\r LIDOCAINE HYDROCHLORIDE  50MG\r 4MG               500mL bag
# 1                     SODIUM CHLORIDE       900MG                    50mL
# 2                     SODIUM CHLORIDE       900MG                  1000mL
# 3                     SODIUM CHLORIDE       900MG                   100mL
# 4                     SODIUM CHLORIDE         9MG  10 x 10mL vial / fiole
#
#                              Route of administration  ... ATC Code  \
# 0                         INTRAVENOUS\r\nINTRAVENOUS  ...    C01BB
# 1                         INTRAVENOUS\r\nINTRAVENOUS  ...    B05XA
# 2                         INTRAVENOUS\r\nINTRAVENOUS  ...    B05XA
# 3                         INTRAVENOUS\r\nINTRAVENOUS  ...    B05XA
# 4  SUBCUTANEOUS\r\nINTRAVENOUS\r\nINTRAMUSCULAR\r...  ...    B05XA
#
#                     ATC description Anticipated start date Actual start date  \
# 0  ANTIARRHYTHMICS, CLASS I AND III             2023-01-09        2023-01-09
# 1           I.V. SOLUTION ADDITIVES             2022-06-09        2022-06-09
# 2           I.V. SOLUTION ADDITIVES                    NaN        2022-10-01
# 3           I.V. SOLUTION ADDITIVES             2022-05-04        2022-05-04
# 4           I.V. SOLUTION ADDITIVES                    NaN        2022-02-01
#
#   Estimated end date Actual end date                               Reason  \
# 0         2023-02-13      2023-02-13        Demand increase for the drug.
# 1         2022-06-23      2022-06-20       Delay in shipping of the drug.
# 2                NaN      2022-11-30  Other (Please describe in comments)
# 3         2022-06-23      2022-06-20       Delay in shipping of the drug.
# 4         2022-05-05      2022-05-05        Demand increase for the drug.
#
#   Date Created Date Updated Tier 3
# 0   2023-01-05   2023-02-14     No
# 1   2022-06-15   2022-06-21     No
# 2   2022-10-03   2022-12-05     No
# 3   2022-05-06   2022-06-21     No
# 4   2021-09-17   2023-01-20     No
#
# [5 rows x 22 columns]

# %%
# Combined all CSV into final dataset
shortage_final = pd.concat([shortage1, shortage2])

# %%
shortage_final
# Out:
#       Report ID  Drug Identification Number Report Type  \
# 0         75200                    437999.0    Shortage
# 1         34506                   1924303.0    Shortage
# 2         91156                     60208.0    Shortage
# 3         99361                     60208.0    Shortage
# 4         91720                     60208.0    Shortage
# ...         ...                         ...         ...
# 8176     103343                   2286424.0    Shortage
# 8177     146373                   2286440.0    Shortage
# 8178     105453                   2286432.0    Shortage
# 8179     105456                   2286440.0    Shortage
# 8180     170399                   2243686.0    Shortage
#
#                                              Brand name          Company Name  \
# 0     (20MMOL/L) POTASSIUM CHLORIDE IN 5% DEXTROSE A...    BAXTER CORPORATION
# 1                    0.9% SODIUM CHLORIDE INJECTION USP  B. BRAUN MEDICAL INC
# 2                   0.9% SODIUM CHLORIDE INJECTION, USP    BAXTER CORPORATION
# 3                   0.9% SODIUM CHLORIDE INJECTION, USP    BAXTER CORPORATION
# 4                   0.9% SODIUM CHLORIDE INJECTION, USP    BAXTER CORPORATION
# ...                                                 ...                   ...
# 8176                                          ZYTRAM XL         PURDUE PHARMA
# 8177                                          ZYTRAM XL         PURDUE PHARMA
# 8178                                          ZYTRAM XL         PURDUE PHARMA
# 8179                                          ZYTRAM XL         PURDUE PHARMA
# 8180                                            ZYVOXAM     PFIZER CANADA ULC
#
#                                   Common or Proper name  \
# 0           Potassium Chloride in 5% Dextrose Injection
# 1                                       Sodium Chloride
# 2                   0.9% Sodium Chloride Injection, USP
# 3                   0.9% SODIUM CHLORIDE INJECTION, USP
# 4                   0.9% SODIUM CHLORIDE INJECTION, USP
# ...                                                 ...
# 8176                                          Zytram XL
# 8177  Tramadol Hydrochloride Controlled Release Tablets
# 8178                                          ZYTRAM XL
# 8179                                          ZYTRAM XL
# 8180                                            ZYVOXAM
#
#                                           Ingredients         Strength(s)  \
# 0     DEXTROSE\r POTASSIUM CHLORIDE\r SODIUM CHLORIDE  5G\r 150MG\r 450MG
# 1                                     SODIUM CHLORIDE                0.9%
# 2                                     SODIUM CHLORIDE               900MG
# 3                                     SODIUM CHLORIDE               900MG
# 4                                     SODIUM CHLORIDE               900MG
# ...                                               ...                 ...
# 8176                           TRAMADOL HYDROCHLORIDE               150MG
# 8177                           TRAMADOL HYDROCHLORIDE               300MG
# 8178                           TRAMADOL HYDROCHLORIDE               200MG
# 8179                           TRAMADOL HYDROCHLORIDE               300MG
# 8180                                        LINEZOLID               100MG
#
#                   Packaging size Route of administration  ... ATC Code  \
# 0                        1000 mL             INTRAVENOUS  ...    B05BB
# 1     100mL, 150mL, 250mL, 500mL             INTRAVENOUS  ...    B05XA
# 2                 50 mL (JB1301)             INTRAVENOUS  ...    B05XA
# 3                 25 mL (JB1300)             INTRAVENOUS  ...    B05XA
# 4                100 mL (JB0043)             INTRAVENOUS  ...    B05XA
# ...                          ...                     ...  ...      ...
# 8176                         60s                    ORAL  ...    N02AX
# 8177                          60            ORAL\r\nORAL  ...    N02AX
# 8178                          60                    ORAL  ...    N02AX
# 8179                          60                    ORAL  ...    N02AX
# 8180                240mL bottle            ORAL\r\nORAL  ...    J01XX
#
#               ATC description Anticipated start date Actual start date  \
# 0              I.V. SOLUTIONS             2019-02-08        2019-02-08
# 1     I.V. SOLUTION ADDITIVES             2017-12-22        2017-12-22
# 2     I.V. SOLUTION ADDITIVES             2019-08-08        2019-08-08
# 3     I.V. SOLUTION ADDITIVES             2019-11-20        2019-11-20
# 4     I.V. SOLUTION ADDITIVES             2019-08-16        2019-08-16
# ...                       ...                    ...               ...
# 8176                  OPIOIDS             2020-01-22        2020-01-20
# 8177                  OPIOIDS             2021-09-29        2021-09-29
# 8178                  OPIOIDS             2020-02-21        2020-04-21
# 8179                  OPIOIDS             2020-03-06        2020-04-12
# 8180     OTHER ANTIBACTERIALS                    NaN        2022-09-28
#
#      Estimated end date Actual end date  \
# 0            2019-02-12      2019-02-12
# 1                   NaN      2019-01-01
# 2            2019-08-29      2019-08-29
# 3            2019-11-29      2019-11-29
# 4            2019-11-08      2019-11-08
# ...                 ...             ...
# 8176         2020-01-31      2020-01-24
# 8177         2021-10-22      2021-10-14
# 8178         2020-04-30      2020-04-22
# 8179         2020-04-30      2020-04-23
# 8180                NaN      2023-01-03
#
#                                           Reason Date Created Date Updated  \
# 0                  Demand increase for the drug.   2019-02-08   2019-02-13
# 1     Disruption of the manufacture of the drug.   2018-01-02   2019-11-06
# 2              Shortage of an active ingredient.   2019-08-08   2019-08-30
# 3                  Demand increase for the drug.   2019-11-20   2019-11-30
# 4              Shortage of an active ingredient.   2019-08-16   2019-11-09
# ...                                          ...          ...          ...
# 8176              Delay in shipping of the drug.   2020-01-15   2020-01-25
# 8177              Delay in shipping of the drug.   2021-09-29   2021-10-15
# 8178              Delay in shipping of the drug.   2020-02-06   2020-04-24
# 8179              Delay in shipping of the drug.   2020-02-06   2020-04-24
# 8180  Disruption of the manufacture of the drug.   2022-09-28   2023-01-04
#
#      Tier 3
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
# ...     ...
# 8176     No
# 8177     No
# 8178     No
# 8179     No
# 8180     No
#
# [17206 rows x 22 columns]

# %%
shortage_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17206 entries, 0 to 8180
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Report ID                   17206 non-null  int64
#  1   Drug Identification Number  17202 non-null  float64
#  2   Report Type                 17206 non-null  object
#  3   Brand name                  17206 non-null  object
#  4   Company Name                17185 non-null  object
#  5   Common or Proper name       17204 non-null  object
#  6   Ingredients                 17129 non-null  object
#  7   Strength(s)                 17143 non-null  object
#  8   Packaging size              17091 non-null  object
#  9   Route of administration     17141 non-null  object
#  10  Shortage status             17206 non-null  object
#  11  Dosage form(s)              17141 non-null  object
#  12  ATC Code                    17123 non-null  object
#  13  ATC description             16945 non-null  object
#  14  Anticipated start date      5198 non-null   object
#  15  Actual start date           15550 non-null  object
#  16  Estimated end date          12959 non-null  object
#  17  Actual end date             15397 non-null  object
#  18  Reason                      17206 non-null  object
#  19  Date Created                17206 non-null  object
#  20  Date Updated                17206 non-null  object
#  21  Tier 3                      17206 non-null  object
# dtypes: float64(1), int64(1), object(20)
# memory usage: 3.0+ MB

# %%
shortage_final.shape
# Out:
# (17206, 22)

# %%
# Clean up all temporary CSV created in directory "Shortage"
directory = "Shortage"
path = os.path.join(cwd, directory)

for f in os.listdir(path):
    if not f.endswith(".csv"):
        continue
    os.remove(os.path.join(path, f))

# %%
# Creating CSV from combined dataset into main directory
shortage_final.to_csv('Shortage/shortage_final.csv', index = False)

# %%
# Removing empty temporary folder "Shortage"
# os.rmdir(path)
