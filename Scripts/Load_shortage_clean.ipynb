# %% [markdown]
# # Analysis of Drug Shortage database

# %% [markdown]
# The data we are using for our analysis contains historical data from 2017 to present. All these records has been reported by the Food and Drug Regulations require drug to sellers are not able to meet demand for a product or when they stop selling a product.

# %% [markdown]
# Shortage reports have 3 different stages and can be resolved as shown below

# %% [markdown]
# # ![image](Shortage_stages.jpg)

# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime
# import xlrd
import warnings
# import matplotlib.pyplot as plt
# import seaborn as sns
from prophet import Prophet
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Shortage data/Zip_Files/shortage_final.csv")

# converting headers in lowercase
df.columns = df.columns.str.lower()

# replacing spaces for "_" in headers
df.columns = df.columns.str.replace(' ', '_')

# Removing NaN actual_start_date and actual_end_date, considering as an incomplete record
df=df.dropna(subset=['actual_start_date','actual_end_date'] )

# Removing Actuals before 2017
df = df.loc[(df['actual_start_date'] >= '2017-01-01')]
# Removing outliers before 2010 for End_date
df = df.loc[(df['actual_end_date'] >= '2010-01-01')]

# Removing duplicates ID Reports
df=df.drop_duplicates("report_id", keep=False)

df.tail()
# Out:
#        report_id  drug_identification_number report_type brand_name  \
# 17163      21685                   2340445.0    Shortage    ZYCLARA
# 17164      52702                   2340445.0    Shortage    ZYCLARA
# 17165      18241                   2257270.0    Shortage      ZYMAR
# 17166      33440                   2257270.0    Shortage      ZYMAR
# 17167      54338                   2243686.0    Shortage    ZYVOXAM
#
#                                   company_name common_or_proper_name  \
# 17163  VALEANT CANADA LP/VALEANT CANADA S.E.C.               ZYCLARA
# 17164  VALEANT CANADA LP/VALEANT CANADA S.E.C.               ZYCLARA
# 17165                             ALLERGAN INC             ZYMAR 1mL
# 17166                             ALLERGAN INC             ZYMAR 1mL
# 17167                        PFIZER CANADA INC               Zyvoxam
#
#         ingredients strength(s) packaging_size route_of_administration  ...  \
# 17163     IMIQUIMOD       3.75%             na                 TOPICAL  ...
# 17164     IMIQUIMOD       3.75%      7.5g pump                 TOPICAL  ...
# 17165  GATIFLOXACIN        0.3%           1 mL              OPHTHALMIC  ...
# 17166  GATIFLOXACIN        0.3%            5mL              OPHTHALMIC  ...
# 17167     LINEZOLID          3G    1x240ml Btl                    ORAL  ...
#
#       atc_code                    atc_description anticipated_start_date  \
# 17163    D06BB  CHEMOTHERAPEUTICS FOR TOPICAL USE                    NaN
# 17164    D06BB  CHEMOTHERAPEUTICS FOR TOPICAL USE                    NaN
# 17165    S01AE                     ANTIINFECTIVES             2017-08-03
# 17166    S01AE                     ANTIINFECTIVES             2019-09-16
# 17167    J01XX               OTHER ANTIBACTERIALS                    NaN
#
#       actual_start_date estimated_end_date actual_end_date  \
# 17163        2017-09-08         2017-09-22      2017-09-22
# 17164        2019-04-01                NaN      2019-07-12
# 17165        2017-08-03         2017-09-18      2017-10-06
# 17166        2019-09-16         2019-09-20      2019-09-18
# 17167        2018-08-21                NaN      2018-10-23
#
#                                            reason date_created date_updated  \
# 17163         Other (Please describe in comments)   2017-09-08   2017-09-25
# 17164         Other (Please describe in comments)   2018-06-20   2019-07-13
# 17165  Disruption of the manufacture of the drug.   2017-08-03   2017-10-13
# 17166  Disruption of the manufacture of the drug.   2017-12-18   2019-09-19
# 17167  Disruption of the manufacture of the drug.   2018-07-04   2018-10-24
#
#       tier_3
# 17163     No
# 17164     No
# 17165     No
# 17166     No
# 17167     No
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# report_id                       int64
# drug_identification_number    float64
# report_type                    object
# brand_name                     object
# company_name                   object
# common_or_proper_name          object
# ingredients                    object
# strength(s)                    object
# packaging_size                 object
# route_of_administration        object
# shortage_status                object
# dosage_form(s)                 object
# atc_code                       object
# atc_description                object
# anticipated_start_date         object
# actual_start_date              object
# estimated_end_date             object
# actual_end_date                object
# reason                         object
# date_created                   object
# date_updated                   object
# tier_3                         object
# dtype: object

# %% [markdown]
# Converting start and end date fields from object to datetime64

# %%
df['actual_start_date'] = df['actual_start_date'].astype('datetime64[D]')

# %%
df['actual_end_date'] = df['actual_end_date'].astype('datetime64[D]')

# %% [markdown]
# Fill NaN drug_identification_number into 0, converting as int

# %%
df['drug_identification_number'] = df['drug_identification_number'].fillna(0)
df['drug_identification_number'] = df['drug_identification_number'].astype('int')

# %%
df.dtypes
# Out:
# report_id                              int64
# drug_identification_number             int32
# report_type                           object
# brand_name                            object
# company_name                          object
# common_or_proper_name                 object
# ingredients                           object
# strength(s)                           object
# packaging_size                        object
# route_of_administration               object
# shortage_status                       object
# dosage_form(s)                        object
# atc_code                              object
# atc_description                       object
# anticipated_start_date                object
# actual_start_date             datetime64[ns]
# estimated_end_date                    object
# actual_end_date               datetime64[ns]
# reason                                object
# date_created                          object
# date_updated                          object
# tier_3                                object
# dtype: object

# %%
# Fill Nat end date with today date
# today = datetime.today().strftime('%Y-%m-%d')
# df = df.fillna(today)

# %% [markdown]
# Calculating # of Days of shortage = actual - start date

# %%
df['Days']= df['actual_end_date']-df['actual_start_date']

# %%
# export to .csv to check data consistency
# df.to_csv("data.csv", index=False)

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13549 entries, 0 to 17167
# Columns: 23 entries, report_id to Days
# dtypes: datetime64[ns](2), int32(1), int64(1), object(18), timedelta64[ns](1)
# memory usage: 2.4+ MB

# %%
din = df['drug_identification_number'].mode()
din
# Out:
# 0    717002
# dtype: int32

# %%
col_list = ['actual_start_date', 'Days']
df2 = df[col_list]
df2
# Out:
#       actual_start_date     Days
# 0            2023-01-09  35 days
# 1            2022-06-09  11 days
# 2            2022-10-01  60 days
# 3            2022-05-04  47 days
# 4            2022-02-01  93 days
# ...                 ...      ...
# 17163        2017-09-08  14 days
# 17164        2019-04-01 102 days
# 17165        2017-08-03  64 days
# 17166        2019-09-16   2 days
# 17167        2018-08-21  63 days
#
# [13549 rows x 2 columns]

# %% [markdown]
# Clean outliers, clean data previous to 2017

# %%
df2 = df2.loc[(df['actual_start_date'] >= '2017-01-01')]
df2
# Out:
#       actual_start_date     Days
# 0            2023-01-09  35 days
# 1            2022-06-09  11 days
# 2            2022-10-01  60 days
# 3            2022-05-04  47 days
# 4            2022-02-01  93 days
# ...                 ...      ...
# 17163        2017-09-08  14 days
# 17164        2019-04-01 102 days
# 17165        2017-08-03  64 days
# 17166        2019-09-16   2 days
# 17167        2018-08-21  63 days
#
# [13549 rows x 2 columns]

# %%
df2.columns = ['ds', 'y']
df2['y'] = df2['y'].dt.days
df2.head()
# Out:
#           ds   y
# 0 2023-01-09  35
# 1 2022-06-09  11
# 2 2022-10-01  60
# 3 2022-05-04  47
# 4 2022-02-01  93

# %% [markdown]
# ### Training the time series model

# %%
p = Prophet(interval_width=0.5, daily_seasonality=True)

# %% [markdown]
# Now train the model.

# %%
model = p.fit(df2)
# Out:
# 12:39:29 - cmdstanpy - INFO - Chain [1] start processing
# 12:39:40 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ### Making predictions and evaluating performance

# %%
future = p.make_future_dataframe(periods=50, freq='D')
future.tail()
# Out:
#              ds
# 1754 2024-02-05
# 1755 2024-02-06
# 1756 2024-02-07
# 1757 2024-02-08
# 1758 2024-02-09

# %%
forecast_prediction = p.predict(future)
forecast_prediction.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2017-01-01  395.476032  335.547847  592.785351   395.476032   395.476032
# 1 2017-01-03  394.404551  132.961817  380.019337   394.404551   394.404551
# 2 2017-01-04  393.868810  148.803254  388.320038   393.868810   393.868810
# 3 2017-01-06  392.797328  142.768179  383.296260   392.797328   392.797328
# 4 2017-01-10  390.654366  135.022009  378.406840   390.654366   390.654366
#
#    additive_terms  additive_terms_lower  additive_terms_upper      daily  ...  \
# 0       58.361804             58.361804             58.361804 -79.460774  ...
# 1     -141.312664           -141.312664           -141.312664 -79.460774  ...
# 2     -129.797081           -129.797081           -129.797081 -79.460774  ...
# 3     -134.703613           -134.703613           -134.703613 -79.460774  ...
# 4     -143.268636           -143.268636           -143.268636 -79.460774  ...
#
#        weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0  152.683515    152.683515    152.683515 -14.860937    -14.860937
# 1  -45.192544    -45.192544    -45.192544 -16.659345    -16.659345
# 2  -32.994660    -32.994660    -32.994660 -17.341647    -17.341647
# 3  -36.967088    -36.967088    -36.967088 -18.275750    -18.275750
# 4  -45.192544    -45.192544    -45.192544 -18.615317    -18.615317
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0    -14.860937                   0.0                         0.0
# 1    -16.659345                   0.0                         0.0
# 2    -17.341647                   0.0                         0.0
# 3    -18.275750                   0.0                         0.0
# 4    -18.615317                   0.0                         0.0
#
#    multiplicative_terms_upper        yhat
# 0                         0.0  453.837836
# 1                         0.0  253.091887
# 2                         0.0  264.071729
# 3                         0.0  258.093716
# 4                         0.0  247.385730
#
# [5 rows x 22 columns]

# %%
plot1 = p.plot(forecast_prediction)

# %%
plot2 = p.plot_components(forecast_prediction)
