# %% [markdown]
# # Analysis of Drug Shortage database

# %% [markdown]
# The data we are using for our analysis contains historical data from 2017 to present. All these records has been reported by the Food and Drug Regulations require drug to sellers are not able to meet demand for a product or when they stop selling a product.

# %% [markdown]
# Shortage reports have 3 different stages and can be resolved as shown below

# %% [markdown]
# # ![image](Shortage_stages.jpg)

# %%
import pandas as pd
import numpy as np
import datetime
from datetime import datetime
import xlrd
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
from prophet import Prophet
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("Shortage data/combined_data.csv")
df.tail()
# Out:
#                        file_name  report_id  drug_identification_number  \
# 19416  2023_Canada_Shortage.xlsx     183684                   2373130.0
# 19417  2023_Canada_Shortage.xlsx     185721                   2153432.0
# 19418  2023_Canada_Shortage.xlsx     181739                   2401606.0
# 19419  2023_Canada_Shortage.xlsx     181295                   2132702.0
# 19420  2023_Canada_Shortage.xlsx     184552                   2132702.0
#
#                                    brand_name                  company_name  \
# 19416  XYLOCAINE 2% WITH EPINEPHRINE 1:200000  ASPEN PHARMACARE CANADA INC.
# 19417                                ZINECARD             PFIZER CANADA ULC
# 19418                     ZOLEDRONIC ACID - Z    SANDOZ CANADA INCORPORATED
# 19419                                  ZOLOFT             UPJOHN CANADA ULC
# 19420                                  ZOLOFT             UPJOHN CANADA ULC
#
#                                  common_or_proper_name  \
# 19416  lidocaine HCI 2% w/epin. 1:200M 10x20mL MD Vial
# 19417                                         ZINECARD
# 19418                                  ZOLEDRONIC ACID
# 19419                                           ZOLOFT
# 19420                                            ZOLFT
#
#                                  ingredients      strength_s packaging_size  \
# 19416  EPINEPHRINE\r LIDOCAINE HYDROCHLORIDE  0.005MG\r 20MG       10 vials
# 19417                            DEXRAZOXANE           250MG      25mL vial
# 19418                        ZOLEDRONIC ACID             4MG            5ML
# 19419                             SERTRALINE            25MG            100
# 19420                             SERTRALINE            25MG            100
#
#           actual_start_date       actual_end_date
# 19416                   NaN                   NaN
# 19417  2023-02-28T00:00:00Z                   NaN
# 19418  2023-01-18T00:00:00Z  2023-01-31T00:00:00Z
# 19419  2023-02-06T00:00:00Z                   NaN
# 19420  2023-02-07T00:00:00Z                   NaN

# %%
df.dtypes
# Out:
# file_name                      object
# report_id                       int64
# drug_identification_number    float64
# brand_name                     object
# company_name                   object
# common_or_proper_name          object
# ingredients                    object
# strength_s                     object
# packaging_size                 object
# actual_start_date              object
# actual_end_date                object
# dtype: object

# %% [markdown]
# Converting start and end date fields from object to datetime64

# %%
df['actual_start_date'] = df['actual_start_date'].astype('datetime64[D]')

# %%
df['actual_end_date'] = df['actual_end_date'].astype('datetime64[D]')

# %% [markdown]
# Fill NaN drug_identification_number into 0, converting as int

# %%
df['drug_identification_number'] = df['drug_identification_number'].fillna(0)
df['drug_identification_number'] = df['drug_identification_number'].astype('int')

# %%
df.dtypes
# Out:
# file_name                             object
# report_id                              int64
# drug_identification_number             int32
# brand_name                            object
# company_name                          object
# common_or_proper_name                 object
# ingredients                           object
# strength_s                            object
# packaging_size                        object
# actual_start_date             datetime64[ns]
# actual_end_date               datetime64[ns]
# dtype: object

# %% [markdown]
# Removing NaN actual_start_date and actual_end_date, considering as an incomplete record

# %%
df=df.dropna(subset=['actual_start_date','actual_end_date'] )

# %% [markdown]
# Removing duplicated Id_reports

# %%
df=df.drop_duplicates("report_id", keep=False)

# %%
# Fill Nat end date with today date
# today = datetime.today().strftime('%Y-%m-%d')
# df = df.fillna(today)

# %% [markdown]
# Calculating # of Days of shortage = actual - start date

# %%
df['Days']= df['actual_end_date']-df['actual_start_date']

# %%
# 
df['file_name'] = df['file_name'].str[0:4]

# %%
df.to_csv("data.csv", index=False)

# %%
df.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11427 entries, 1 to 19418
# Columns: 12 entries, file_name to Days
# dtypes: datetime64[ns](2), int32(1), int64(1), object(7), timedelta64[ns](1)
# memory usage: 1.1+ MB

# %%
din = df['drug_identification_number'].mode()
din
# Out:
# 0    717002
# dtype: int32

# %% [markdown]
# Clean outliers, clean data previous to 2017

# %%
df2 = df.drop(['file_name',	'report_id',	'drug_identification_number',	'brand_name',	'company_name',	'common_or_proper_name',	'ingredients',	'strength_s',	'packaging_size','actual_end_date'],axis=1)
df2 = df2.loc[(df['actual_start_date'] >= '2017-01-01')]

# %%
df2
# Out:
#       actual_start_date     Days
# 1            2017-11-15   6 days
# 2            2018-03-01  28 days
# 4            2018-01-19  42 days
# 6            2017-11-17 122 days
# 8            2017-09-13 428 days
# ...                 ...      ...
# 19389        2023-01-09   9 days
# 19405        2023-01-26  19 days
# 19406        2023-01-11  34 days
# 19410        2023-01-31   7 days
# 19418        2023-01-18  13 days
#
# [11138 rows x 2 columns]

# %%
df2.columns = ['ds', 'y']
df2['y'] = df2['y'].dt.days
df2.head()
# Out:
#           ds    y
# 1 2017-11-15    6
# 2 2018-03-01   28
# 4 2018-01-19   42
# 6 2017-11-17  122
# 8 2017-09-13  428

# %% [markdown]
# ### Training the time series model

# %%
p = Prophet(interval_width=0.5, daily_seasonality=True)

# %% [markdown]
# Now train the model.

# %%
model = p.fit(df2)
# Out:
# 12:00:12 - cmdstanpy - INFO - Chain [1] start processing
# 12:00:25 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# ### Making predictions and evaluating performance

# %%
future = p.make_future_dataframe(periods=50, freq='D')
future.tail()
# Out:
#              ds
# 1576 2024-02-05
# 1577 2024-02-06
# 1578 2024-02-07
# 1579 2024-02-08
# 1580 2024-02-09

# %%
forecast_prediction = p.predict(future)
forecast_prediction.head()
# Out:
#           ds       trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2017-01-01  394.164176  322.724979  561.987217   394.164176   394.164176
# 1 2017-01-03  393.208393  116.948411  354.657900   393.208393   393.208393
# 2 2017-01-04  392.730502  131.135705  379.283781   392.730502   392.730502
# 3 2017-01-06  391.774720  128.607577  362.651206   391.774720   391.774720
# 4 2017-01-10  389.863154  101.580975  342.828727   389.863154   389.863154
#
#    additive_terms  additive_terms_lower  additive_terms_upper      daily  ...  \
# 0       59.666057             59.666057             59.666057 -85.430957  ...
# 1     -157.691689           -157.691689           -157.691689 -85.430957  ...
# 2     -142.426641           -142.426641           -142.426641 -85.430957  ...
# 3     -150.371327           -150.371327           -150.371327 -85.430957  ...
# 4     -156.275886           -156.275886           -156.275886 -85.430957  ...
#
#        weekly  weekly_lower  weekly_upper     yearly  yearly_lower  \
# 0  163.826287    163.826287    163.826287 -18.729273    -18.729273
# 1  -52.442103    -52.442103    -52.442103 -19.818629    -19.818629
# 2  -36.929921    -36.929921    -36.929921 -20.065763    -20.065763
# 3  -44.914736    -44.914736    -44.914736 -20.025634    -20.025634
# 4  -52.442103    -52.442103    -52.442103 -18.402826    -18.402826
#
#    yearly_upper  multiplicative_terms  multiplicative_terms_lower  \
# 0    -18.729273                   0.0                         0.0
# 1    -19.818629                   0.0                         0.0
# 2    -20.065763                   0.0                         0.0
# 3    -20.025634                   0.0                         0.0
# 4    -18.402826                   0.0                         0.0
#
#    multiplicative_terms_upper        yhat
# 0                         0.0  453.830233
# 1                         0.0  235.516705
# 2                         0.0  250.303861
# 3                         0.0  241.403393
# 4                         0.0  233.587269
#
# [5 rows x 22 columns]

# %%
plot1 = p.plot(forecast_prediction)

# %%
plot2 = p.plot_components(forecast_prediction)
